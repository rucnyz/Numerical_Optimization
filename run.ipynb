# %%
from utils import algo_display, get_fun
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams["font.sans-serif"] = ["SimHei"]  # 用来正常显示中文标签
plt.rcParams["axes.unicode_minus"] = False  # 用来正常显示负号

# %%
# 设置x的维度
n = 10

# %% [markdown]
# ## Watson函数的各算法结果

# %%
x0 = np.zeros((n, 1))
fun, grad, Hessan = get_fun("Watson", n)
print("Watson函数使用各算法对比：\n")
delta_d, delta_m, delta_S, delta_D, delta_B = algo_display(fun, grad, Hessan, x0)
# Out:
# Watson函数使用各算法对比：
#
# 阻尼牛顿法：
# 第0次迭代  函数值为1.5297  delta为35.1623
# Gk奇异，迭代结束
# ---------------------------------------------------------------
# 修正牛顿法：
# 第0次迭代  函数值为17.9453  delta为65.7434
# 第100次迭代  函数值为0.1510  delta为0.8544
# 第200次迭代  函数值为0.0980  delta为0.4310
# 第300次迭代  函数值为0.0750  delta为0.3160
# 第400次迭代  函数值为0.0560  delta为0.2619
# 第500次迭代  函数值为0.0418  delta为0.2580
# 第600次迭代  函数值为0.0317  delta为0.2110
# 第700次迭代  函数值为0.0214  delta为0.1713
# 第800次迭代  函数值为0.0144  delta为0.2001
# 第900次迭代  函数值为0.0089  delta为0.1963
# 第1000次迭代  函数值为0.0056  delta为0.1303
# 第1100次迭代  函数值为0.0038  delta为0.0993
# 第1200次迭代  函数值为0.0026  delta为0.0835
# 第1300次迭代  函数值为0.0016  delta为0.0995
# 第1400次迭代  函数值为0.0010  delta为0.0704
# 第1500次迭代  函数值为0.0006  delta为0.0506
# 第1600次迭代  函数值为0.0004  delta为0.0389
# 第1700次迭代  函数值为0.0003  delta为0.0268
# 第1800次迭代  函数值为0.0002  delta为0.0210
# 第1900次迭代  函数值为0.0001  delta为0.0176
# 第2000次迭代  函数值为0.0001  delta为0.0136
# 第2100次迭代  函数值为0.0001  delta为0.0114
#
# 运行结束
# 成功收敛！    总计迭代次数2149    总耗时为284.7774s
# 收敛点为[[ 0.00491535]
#  [ 0.99465553]
#  [ 0.05496448]
#  [ 0.17912354]
#  [ 0.18369363]
#  [ 0.09693604]
#  [ 0.00471363]
#  [-0.03896393]
#  [-0.00870727]
#  [ 0.10346216]]    函数值为0.0001    最终delta为0.0099
# ---------------------------------------------------------------
# 拟牛顿法：SR1
# 第0次迭代  函数值为17.9453  delta为65.7434
#
# 运行结束
# 成功收敛！    总计迭代次数21    总耗时为0.6532s
# 收敛点为[[-7.21287177e-04]
#  [ 1.00054943e+00]
#  [ 3.57475106e-03]
#  [ 2.75529747e-01]
#  [ 1.46488128e-01]
#  [ 3.23679166e-02]
#  [-4.18132106e-03]
#  [ 8.74249845e-03]
#  [ 3.66161748e-02]
#  [ 5.59939150e-02]]    函数值为0.0000    最终delta为0.0018
# ---------------------------------------------------------------
# 拟牛顿法：DFP
# 第0次迭代  函数值为17.9453  delta为65.7434
#
# 运行结束
# 成功收敛！    总计迭代次数71    总耗时为2.1545s
# 收敛点为[[ 4.69284263e-04]
#  [ 1.00012707e+00]
#  [ 7.80126084e-03]
#  [ 2.69681462e-01]
#  [ 1.46792394e-01]
#  [ 3.82587569e-02]
#  [-1.19264305e-03]
#  [ 5.07797361e-03]
#  [ 3.10350002e-02]
#  [ 6.08276620e-02]]    函数值为0.0000    最终delta为0.0083
# ---------------------------------------------------------------
# 拟牛顿法：BFGS
# 第0次迭代  函数值为17.9453  delta为65.7434
#
# 运行结束
# 成功收敛！    总计迭代次数20    总耗时为0.6319s
# 收敛点为[[-5.93586847e-04]
#  [ 1.00062321e+00]
#  [ 3.43488978e-03]
#  [ 2.75700730e-01]
#  [ 1.46736826e-01]
#  [ 3.23623481e-02]
#  [-4.31767082e-03]
#  [ 8.67376863e-03]
#  [ 3.66808026e-02]
#  [ 5.60790645e-02]]    函数值为0.0000    最终delta为0.0016
# ---------------------------------------------------------------

# %%
plt.figure(dpi = 120)
plt.plot(delta_m, label = "修正牛顿法")
plt.plot(delta_S, label = "拟牛顿法-SR1")
plt.plot(delta_D, label = "拟牛顿法-DFP")
plt.plot(delta_B, label = "拟牛顿法-BFGS")
plt.legend()
plt.ylim(0, 0.1)
# Out:
# (0.0, 0.1)

# %% [markdown]
# ## DBV函数的各算法结果

# %%
x0 = np.array([((i + 1) / (n + 1)) * ((i + 1) / (n + 1) - 1) for i in range(n)])
x0 = x0.reshape((n, 1))
fun, grad, Hessan = get_fun("DBV", n)
print("DBV函数使用各算法对比：\n")
delta_d, delta_m, delta_S, delta_D, delta_B = algo_display(fun, grad, Hessan, x0)
# Out:
# DBV函数使用各算法对比：
#
# 阻尼牛顿法：
# Gk奇异，迭代结束
# ---------------------------------------------------------------
# 修正牛顿法：
# 第0次迭代  函数值为0.0040  delta为0.0863
# 第100次迭代  函数值为0.0028  delta为0.0114
# <lambdifygenerated-6>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array([[((6/121)*x1 + 72/1331)*(2*x1 - x2 + (1/242)*(x1 + 12/11)**3) + ((6/121)*x1 + 72/1331)*(2*x1 - x10 - x2 + (1/242)*(x1 + 12/11)**3) + 2*((3/242)*(x1 + 12/11)**2 + 2)*((3/121)*(x1 + 12/11)**2 + 4) + 2, -6/121*(x1 + 12/11)**2 - 3/121*(x2 + 13/11)**2 - 12, 2, 0, 0, 0, 0, 0, 0, -3/121*(x1 + 12/11)**2 - 4], [-6/121*(x1 + 12/11)**2 - 3/121*(x2 + 13/11)**2 - 12, ((6/121)*x2 + 78/1331)*(-x1 + 2*x2 - x3 + (1/242)*(x2 + 13/11)**3) + ((3/242)*(x2 + 13/11)**2 + 2)*((3/121)*(x2 + 13/11)**2 + 4) + 6, -3/121*(x2 + 13/11)**2 - 3/121*(x3 + 14/11)**2 - 8, 2, 0, 0, 0, 0, 0, 2], [2, -3/121*(x2 + 13/11)**2 - 3/121*(x3 + 14/11)**2 - 8, ((6/121)*x3 + 84/1331)*(-x2 + 2*x3 - x4 + (1/242)*(x3 + 14/11)**3) + ((3/242)*(x3 + 14/11)**2 + 2)*((3/121)*(x3 + 14/11)**2 + 4) + 4, -3/121*(x3 + 14/11)**2 - 3/121*(x4 + 15/11)**2 - 8, 2, 0, 0, 0, 0, 0], [0, 2, -3/121*(x3 + 14/11)**2 - 3/121*(x4 + 15/11)**2 - 8, ((6/121)*x4 + 90/1331)*(-x3 + 2*x4 - x5 + (1/242)*(x4 + 15/11)**3) + ((3/242)*(x4 + 15/11)**2 + 2)*((3/121)*(x4 + 15/11)**2 + 4) + 4, -3/121*(x4 + 15/11)**2 - 3/121*(x5 + 16/11)**2 - 8, 2, 0, 0, 0, 0], [0, 0, 2, -3/121*(x4 + 15/11)**2 - 3/121*(x5 + 16/11)**2 - 8, ((6/121)*x5 + 96/1331)*(-x4 + 2*x5 - x6 + (1/242)*(x5 + 16/11)**3) + ((3/242)*(x5 + 16/11)**2 + 2)*((3/121)*(x5 + 16/11)**2 + 4) + 4, -3/121*(x5 + 16/11)**2 - 3/121*(x6 + 17/11)**2 - 8, 2, 0, 0, 0], [0, 0, 0, 2, -3/121*(x5 + 16/11)**2 - 3/121*(x6 + 17/11)**2 - 8, ((6/121)*x6 + 102/1331)*(-x5 + 2*x6 - x7 + (1/242)*(x6 + 17/11)**3) + ((3/242)*(x6 + 17/11)**2 + 2)*((3/121)*(x6 + 17/11)**2 + 4) + 4, -3/121*(x6 + 17/11)**2 - 3/121*(x7 + 18/11)**2 - 8, 2, 0, 0], [0, 0, 0, 0, 2, -3/121*(x6 + 17/11)**2 - 3/121*(x7 + 18/11)**2 - 8, ((6/121)*x7 + 108/1331)*(-x6 + 2*x7 - x8 + (1/242)*(x7 + 18/11)**3) + ((3/242)*(x7 + 18/11)**2 + 2)*((3/121)*(x7 + 18/11)**2 + 4) + 4, -3/121*(x7 + 18/11)**2 - 3/121*(x8 + 19/11)**2 - 8, 2, 0], [0, 0, 0, 0, 0, 2, -3/121*(x7 + 18/11)**2 - 3/121*(x8 + 19/11)**2 - 8, ((6/121)*x8 + 114/1331)*(-x7 + 2*x8 - x9 + (1/242)*(x8 + 19/11)**3) + ((3/242)*(x8 + 19/11)**2 + 2)*((3/121)*(x8 + 19/11)**2 + 4) + 4, -3/121*(x8 + 19/11)**2 - 3/121*(x9 + 20/11)**2 - 8, 2], [0, 0, 0, 0, 0, 0, 2, -3/121*(x8 + 19/11)**2 - 3/121*(x9 + 20/11)**2 - 8, ((6/121)*x9 + 120/1331)*(-x10 - x8 + 2*x9 + (1/242)*(x9 + 20/11)**3) + ((3/242)*(x9 + 20/11)**2 + 2)*((3/121)*(x9 + 20/11)**2 + 4) + 4, -3/121*(x10 + 21/11)**2 - 3/121*(x9 + 20/11)**2 - 8], [-3/121*(x1 + 12/11)**2 - 4, 2, 0, 0, 0, 0, 0, 2, -3/121*(x10 + 21/11)**2 - 3/121*(x9 + 20/11)**2 - 8, ((6/121)*x10 + 126/1331)*(2*x10 - x9 + (1/242)*(x10 + 21/11)**3) + ((3/242)*(x10 + 21/11)**2 + 2)*((3/121)*(x10 + 21/11)**2 + 4) + 4]])
# 运行结束
# 成功收敛！    总计迭代次数168    总耗时为0.5470s
# 收敛点为[[-0.08524922]
#  [-0.13458414]
#  [-0.17366788]
#  [-0.19936717]
#  [-0.21063625]
#  [-0.20654762]
#  [-0.18790961]
#  [-0.15577924]
#  [-0.11235187]
#  [-0.05959603]]    函数值为0.0025    最终delta为0.0100
# ---------------------------------------------------------------
# 拟牛顿法：SR1
# 第0次迭代  函数值为0.0040  delta为0.0863
#
# 运行结束
# 成功收敛！    总计迭代次数10    总耗时为0.0330s
# 收敛点为[[-0.04126475]
#  [-0.0595202 ]
#  [-0.07398455]
#  [-0.08458677]
#  [-0.09111072]
#  [-0.09312839]
#  [-0.08994361]
#  [-0.08055274]
#  [-0.06362107]
#  [-0.03746256]]    函数值为0.0015    最终delta为0.0004
# ---------------------------------------------------------------
# 拟牛顿法：DFP
# 第0次迭代  函数值为0.0040  delta为0.0863
#
# 运行结束
# 成功收敛！    总计迭代次数32    总耗时为0.0920s
# 收敛点为[[-0.04251264]
#  [-0.06117571]
#  [-0.07778752]
#  [-0.09152566]
#  [-0.10172505]
#  [-0.10723813]
#  [-0.10557424]
#  [-0.09394061]
#  [-0.07174644]
#  [-0.04061487]]    函数值为0.0015    最终delta为0.0096
# ---------------------------------------------------------------
# 拟牛顿法：BFGS
# 第0次迭代  函数值为0.0040  delta为0.0863
#
# 运行结束
# 成功收敛！    总计迭代次数12    总耗时为0.0360s
# 收敛点为[[-0.04139914]
#  [-0.05933435]
#  [-0.07245234]
#  [-0.08118984]
#  [-0.08635422]
#  [-0.08826554]
#  [-0.08621669]
#  [-0.07849467]
#  [-0.06293729]
#  [-0.03743844]]    函数值为0.0015    最终delta为0.0039
# ---------------------------------------------------------------

# %%
plt.figure(dpi = 120)
plt.plot(delta_m, label = "修正牛顿法")
plt.plot(delta_S, label = "拟牛顿法-SR1")
plt.plot(delta_D, label = "拟牛顿法-DFP")
plt.plot(delta_B, label = "拟牛顿法-BFGS")
plt.legend()
plt.ylim(0, 0.1)
# Out:
# (0.0, 0.1)
